# %% [markdown]
# # Synthetic Generation of Financial Time Series

# %% [markdown]
# ## D_r(real data)

# %%
import numpy as np
import pandas as pd
import plotly.express as px
from flowgen import stock_5y, synthesis, regime_analysis, plot_regime_switching
# Out:
# /home/rishabh/miniconda3/envs/ts-env/lib/python3.12/site-packages/fs_gcsfs/__init__.py:2: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import get_distribution, DistributionNotFound

# %%
nvda = stock_5y("NVDA")

# %%
nvda.head()
# Out:
#          date     close
# 0  2020-12-04  13.55825
# 1  2020-12-07  13.60675
# 2  2020-12-08  13.35000
# 3  2020-12-09  12.93075
# 4  2020-12-10  12.97225

# %%
fig = px.line(nvda.close, title='NVIDIA Closing Price')
fig.show()

# %% [markdown]
# ### Regime Switching Analysis on Real Data

# %%
nvda_regime = regime_analysis(nvda)

# %%
plot_regime_switching(nvda, nvda_regime)

# %% [markdown]
# ## Synthetic Data Generation D_g

# %%
nvda_synth = synthesis(nvda)
synth_v_real = pd.DataFrame({'Synthetic': nvda_synth['close'], 'Actual': nvda['close']})
# Out:
# [########################################] | 100% Completed | 100.87 ms
# [########################################] | 100% Completed | 101.40 ms
# [########################################] | 100% Completed | 100.98 ms
# INFO: 2025-12-04 13:49:36,113 [SYNTHESIZER] - Initializing Time Series SYNTHESIZER.
# Validate the segmentation strategy.
# INFO: 2025-12-04 13:49:36,115 [SYNTHESIZER] - Number columns considered for synth: 2
# INFO: 2025-12-04 13:49:36,389 [SYNTHESIZER] - Starting the synthetic data modeling process over 1x1 blocks.
# INFO: 2025-12-04 13:49:36,390 [SYNTHESIZER] - Preprocess segment
# INFO: 2025-12-04 13:49:36,392 [SYNTHESIZER] - Synthesizer init.
# INFO: 2025-12-04 13:49:36,392 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2025-12-04 13:49:36,611 [SYNTHESIZER] - Start generating model samples.
# INFO: 2025-12-04 13:49:36,612 [SYNTHESIZER] - Init Dask cluster for sampling.
# ...

# %%
fig = px.line(synth_v_real, y=synth_v_real.columns,
             title='Actual vs Synthetic')
fig.show()

# %% [markdown]
# ### Regime Switching Analysis on Synthetic Data

# %%
nvda_synth_regime = regime_analysis(nvda_synth)

# %%
plot_regime_switching(nvda_synth, nvda_synth_regime)

# %%
# Transition matrix from regime list

# %% [markdown]
# ### Agreement Rate (Measures the usability of the synthetic data)
