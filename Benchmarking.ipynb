# %% [markdown]
# # Synthetic Generation of Financial Time Series

# %% [markdown]
# ## D_r(real data)

# %%
import numpy as np
import pandas as pd
import plotly.express as px
from flowgen import stock_5y, synthesis
# Out:
# /home/rishabh/miniconda3/envs/ts-env/lib/python3.12/site-packages/fs_gcsfs/__init__.py:2: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import get_distribution, DistributionNotFound

# %%
nvda = stock_5y("NVDA")

# %%
nvda.head()
# Out:
#          date     close
# 0  2020-12-03  13.39600
# 1  2020-12-04  13.55825
# 2  2020-12-07  13.60675
# 3  2020-12-08  13.35000
# 4  2020-12-09  12.93075

# %%
fig = px.line(nvda.close, title='NVIDIA Closing Price')
fig.show()

# %% [markdown]
# #### Split D_r

# %%
X_train, X_test = X[:800], X[800:]
y_train, y_test = y[:800], y[800:]

# %%
X_train.size

# %% [markdown]
# ## Synthetic Data Generation D_g

# %%
nvda_synth = synthesis(nvda)
synth_v_real = pd.DataFrame({'Synthetic': nvda_synth['close'], 'Actual': nvda['close']})
# Out:
# [########################################] | 100% Completed | 101.18 ms
# [########################################] | 100% Completed | 101.67 ms
# [########################################] | 100% Completed | 101.14 ms
# INFO: 2025-12-03 14:36:55,545 [SYNTHESIZER] - Initializing Time Series SYNTHESIZER.
# Validate the segmentation strategy.
# INFO: 2025-12-03 14:36:55,547 [SYNTHESIZER] - Number columns considered for synth: 2
# INFO: 2025-12-03 14:36:55,814 [SYNTHESIZER] - Starting the synthetic data modeling process over 1x1 blocks.
# INFO: 2025-12-03 14:36:55,814 [SYNTHESIZER] - Preprocess segment
# INFO: 2025-12-03 14:36:55,815 [SYNTHESIZER] - Synthesizer init.
# INFO: 2025-12-03 14:36:55,816 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2025-12-03 14:36:56,325 Pandas backend loaded 2.2.3
# INFO: 2025-12-03 14:36:56,330 Numpy backend loaded 1.26.4
# INFO: 2025-12-03 14:36:56,331 Pyspark backend NOT loaded
# INFO: 2025-12-03 14:36:56,331 Python backend loaded
# INFO: 2025-12-03 14:37:05,438 [SYNTHESIZER] - Start generating model samples.
# INFO: 2025-12-03 14:37:05,439 [SYNTHESIZER] - Init Dask cluster for sampling.
# INFO: 2025-12-03 14:37:05,462 To route to workers diagnostics web server please install jupyter-server-proxy: python -m pip install jupyter-server-proxy
# INFO: 2025-12-03 14:37:05,464 State start
# INFO: 2025-12-03 14:37:05,465 Found stale lock file and directory '/tmp/dask-scratch-space/scheduler-9wq71c8f', purging
# INFO: 2025-12-03 14:37:05,468   Scheduler at:     tcp://127.0.0.1:37691
# INFO: 2025-12-03 14:37:05,469   dashboard at:  http://127.0.0.1:8787/status
# INFO: 2025-12-03 14:37:05,469 Registering Worker plugin shuffle
# INFO: 2025-12-03 14:37:05,480         Start Nanny at: 'tcp://127.0.0.1:37431'
# INFO: 2025-12-03 14:37:05,482         Start Nanny at: 'tcp://127.0.0.1:32965'
# INFO: 2025-12-03 14:37:05,485         Start Nanny at: 'tcp://127.0.0.1:33163'
# INFO: 2025-12-03 14:37:05,488         Start Nanny at: 'tcp://127.0.0.1:45237'
# INFO: 2025-12-03 14:37:06,138 Register worker addr: tcp://127.0.0.1:39009 name: 1
# INFO: 2025-12-03 14:37:06,140 Starting worker compute stream, tcp://127.0.0.1:39009
# INFO: 2025-12-03 14:37:06,141 Starting established connection to tcp://127.0.0.1:55846
# INFO: 2025-12-03 14:37:06,142 Register worker addr: tcp://127.0.0.1:40315 name: 3
# INFO: 2025-12-03 14:37:06,143 Starting worker compute stream, tcp://127.0.0.1:40315
# INFO: 2025-12-03 14:37:06,143 Starting established connection to tcp://127.0.0.1:55856
# INFO: 2025-12-03 14:37:06,144 Register worker addr: tcp://127.0.0.1:42619 name: 0
# INFO: 2025-12-03 14:37:06,145 Starting worker compute stream, tcp://127.0.0.1:42619
# INFO: 2025-12-03 14:37:06,145 Starting established connection to tcp://127.0.0.1:55864
# INFO: 2025-12-03 14:37:06,147 Register worker addr: tcp://127.0.0.1:36947 name: 2
# INFO: 2025-12-03 14:37:06,148 Starting worker compute stream, tcp://127.0.0.1:36947
# INFO: 2025-12-03 14:37:06,148 Starting established connection to tcp://127.0.0.1:55878
# INFO: 2025-12-03 14:37:06,158 Receive client connection: Client-28399d3a-d04d-11f0-b89b-5c2886b2d3d9
# INFO: 2025-12-03 14:37:06,159 Starting established connection to tcp://127.0.0.1:55892
# INFO: 2025-12-03 14:37:06,178 [SYNTHESIZER] - Postprocessing.
# INFO: 2025-12-03 14:37:06,181 [SYNTHESIZER] - Numerical clipping
# /home/rishabh/miniconda3/envs/ts-env/lib/python3.12/site-packages/dask/dataframe/__init__.py:49: FutureWarning:
# Dask dataframe query planning is disabled because dask-expr is not installed.
#
# You can install it with `pip install dask[dataframe]` or `conda install dask`.
# This will raise in a future version.
#
#   warnings.warn(msg, FutureWarning)
# /home/rishabh/miniconda3/envs/ts-env/lib/python3.12/site-packages/dask/utils.py:1226: FutureWarning: Series.view is deprecated and will be removed in a future version. Use ``astype`` as an alternative to change the dtype.
#   return getattr(__obj, self.method)(*args, **kwargs)
# /home/rishabh/miniconda3/envs/ts-env/lib/python3.12/site-packages/dask/dataframe/__init__.py:49: FutureWarning:
# Dask dataframe query planning is disabled because dask-expr is not installed.
#
# You can install it with `pip install dask[dataframe]` or `conda install dask`.
# This will raise in a future version.
#
#   warnings.warn(msg, FutureWarning)

# %%
fig = px.line(synth_v_real, y=synth_v_real.columns,
             title='Actual vs Synthetic')
fig.show()

# %% [markdown]
# ## Task [T]: Regression
# ## Algorithm [A]: Linear Regression

# %% [markdown]
# #### Linear Regression model on D_r

# %%
from sklearn.linear_model import LinearRegression

model_r = LinearRegression()
model_r.fit(X_train, y_train)
model_r.score(X_train, y_train)

# %% [markdown]
# #### Evaluation of the model_r on D_r test

# %%
y_r_pred = model_r.predict(X_test).astype(int)
fig = px.line(y_r_pred, title='Linear Trend, Actual predictions')
fig.show()

# %% [markdown]
# #### Linear Regression model on D_g

# %%
X_g, y_g = np.array(f0_synth['time_idx']).reshape(-1,1), np.array(f0_synth['f0']).reshape(-1,1)

model_g = LinearRegression()
model_g.fit(X_g, y_g)
model_g.score(X_g, y_g)

# %% [markdown]
# #### Evaluation of the model_g on D_r test

# %%
y_g_pred = model_g.predict(X_test).astype(int)
fig = px.line(y_g_pred, title='Predictions, trained using the generated model')
fig.show()

# %%
X_test.size

# %% [markdown]
# ### Agreement Rate (Measures the usability of the synthetic data)

# %%
r_agree = np.sum(y_g_pred == y_r_pred) / X_test.size
r_agree

# %% [markdown]
# # Seasonal Time Series
